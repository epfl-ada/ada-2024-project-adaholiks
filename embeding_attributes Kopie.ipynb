# %%
import pandas as pd
import requests
import pyarrow.feather as feather

# %%
articles_df = pd.read_feather('Data/dataframes/article_dataframe_embedding_distance.feather')
l_paths_df = pd.read_feather('Data/dataframes/length_filt_finished_paths.feather')
t_paths_df = pd.read_feather('Data/dataframes/time_filt_finished_paths.feather')

# %%
articles_df['embeddings'].shape
# Out:
# (4604,)

# %%
# check that all articles have embeddings
articles_df['embeddings'].value_counts().sum() == articles_df.shape[0]
# Out:
# np.True_

# %%
l_paths_df
# Out:
#         hashedIpAddress   timestamp  durationInSec  \
# 0      0935d79e398bbc10  1323114272            203
# 1      60c910147d51bc1a  1351315069            187
# 2      3a11233c52f824f8  1336283594            178
# 3      71773902171ac6b7  1256870474             25
# 4      77d69c7906320c92  1322615091             41
# ...                 ...         ...            ...
# 21641  5e5b3e43164d9fb9  1366728083            423
# 21642  470fc8241582c7eb  1249681545            525
# 21643  1e68f2ea6fb133d3  1357686675            186
# 21644  473d6ac602c2b198  1318968881            110
# 21645  5d77a62b4b42d55f  1374497036            244
#
#                                                     path  rating  finished  \
# 0      Theatre;India;Bay_of_Bengal;Indian_Ocean;Afric...     NaN      True
# 1      Brain;Computer_science;Internet;World_Wide_Web...     3.0      True
# 2      Family;United_States;Judaism;Olive_oil;Tree;Ap...     NaN      True
# 3      Luminiferous_aether;Special_relativity;Time;Clock     1.0      True
# 4                 Corn_oil;Maize;Southern_Africa;Mayotte     2.0      True
# ...                                                  ...     ...       ...
# 21641  Fusarium;Cornea;Human;United_Nations;United_St...     3.0      True
# 21642  Scheme_programming_language;Functional_program...     5.0      True
# 21643  Horatio_Nelson,_1st_Viscount_Nelson;England;St...     3.0      True
# 21644  Scheme_programming_language;Functional_program...     NaN      True
# 21645  Jehovah;Switzerland;Energy;Photosynthesis;Pigm...     2.0      True
#
#       failure_reason                        start_article  \
# 0               None                              Theatre
# 1               None                                Brain
# 2               None                               Family
# 3               None                  Luminiferous_aether
# 4               None                             Corn_oil
# ...              ...                                  ...
# 21641           None                             Fusarium
# 21642           None          Scheme_programming_language
# 21643           None  Horatio_Nelson,_1st_Viscount_Nelson
# 21644           None          Scheme_programming_language
# 21645           None                              Jehovah
#
#                     target_article  identifier  \
# 0                            Zebra       38072
# 1                        Telephone        6500
# 2                            Cider       13911
# 3                            Clock       23616
# 4                          Mayotte       10144
# ...                            ...         ...
# 21641  Tropical_Storm_Delta_(2005)       15281
# 21642              Tasmanian_Devil       33670
# 21643         Upsilon_Andromedae_d       18649
# 21644    Effects_of_global_warming       33669
# 21645                Chromatophore       20816
#
#                                                full_path  \
# 0      [Theatre, India, Bay_of_Bengal, Indian_Ocean, ...
# 1      [Brain, Computer_science, Internet, World_Wide...
# 2      [Family, United_States, Judaism, Olive_oil, Tr...
# 3      [Luminiferous_aether, Special_relativity, Time...
# 4            [Corn_oil, Maize, Southern_Africa, Mayotte]
# ...                                                  ...
# 21641  [Fusarium, Cornea, Human, United_Nations, Unit...
# 21642  [Scheme_programming_language, Functional_progr...
# 21643  [Horatio_Nelson,_1st_Viscount_Nelson, England,...
# 21644  [Scheme_programming_language, Functional_progr...
# 21645  [Jehovah, Switzerland, Energy, Photosynthesis,...
#
#                                          simplified_path  distance  \
# 0      [Theatre, India, Bay_of_Bengal, Indian_Ocean, ...       3.0
# 1      [Brain, Computer_science, Internet, World_Wide...       3.0
# 2      [Family, United_States, Judaism, Olive_oil, Tr...       3.0
# 3      [Luminiferous_aether, Special_relativity, Time...       3.0
# 4            [Corn_oil, Maize, Southern_Africa, Mayotte]       3.0
# ...                                                  ...       ...
# 21641  [Fusarium, Cornea, Human, United_Nations, Unit...       6.0
# 21642  [Scheme_programming_language, Functional_progr...       6.0
# 21643  [Horatio_Nelson,_1st_Viscount_Nelson, England,...       6.0
# 21644  [Scheme_programming_language, Functional_progr...       6.0
# 21645  [Jehovah, Switzerland, Energy, Photosynthesis,...       6.0
#
#        full_path_length  simplified_path_length
# 0                     8                       7
# 1                     4                       4
# 2                     6                       6
# 3                     3                       3
# 4                     3                       3
# ...                 ...                     ...
# 21641                 8                       8
# 21642                13                      10
# 21643                 6                       6
# 21644                 6                       6
# 21645                 6                       6
#
# [21646 rows x 15 columns]

# %%
articles_df.head(1)
# Out:
#              article        article_unrendered_unicode  \
# 0  Áedán_mac_Gabráin  %C3%81ed%C3%A1n_mac_Gabr%C3%A1in
#
#                                             category         linkSource  \
# 0  [subject.History.British_History.British_Histo...  Áedán_mac_Gabráin
#
#                                           linkTarget  \
# 0  [Bede, Columba, Dál_Riata, Great_Britain, Irel...
#
#                                            distances  \
# 0  {'10th_century': 3.0, '11th_century': 3.0, '12...
#
#                                           plain_text  incoming_links  \
# 0     #copyright\n\nÁedán mac Gabráin\n\n2007 Sch...               0
#
#    num_hyperlinks  num_characters  hyperlink_density  \
# 0              11           11612           0.000947
#
#                                           embeddings  \
# 0  [-0.1292391121387481, 0.0236219353973865, -0.0...
#
#    average_outgoing_article_title_cosine_distance
# 0                                        0.785123

# %%
# 1. extract the simplified path and start article => new df of 2 columns 
# 2. a function that iterates over the simplified paths and extracts the corresponding vector embeddings from the articles_df
# 3. apply the function
# 4. compute the cosine similarty between all the articles and the target article (add a new column to the df (list of cosine similarities))
# 5. then iterate over the df to average the cosine similarities for each article

# what this can tell us? are the articles that get high scores in cosine similarity to the target on average the ones that have high scores?
# if so this might indicate theat these articles tend to appear in specific paths, or that the target articles favor certain topics...

# %%
# 1. 

df = l_paths_df[['simplified_path']]

df
# Out:
#                                          simplified_path
# 0      [Theatre, India, Bay_of_Bengal, Indian_Ocean, ...
# 1      [Brain, Computer_science, Internet, World_Wide...
# 2      [Family, United_States, Judaism, Olive_oil, Tr...
# 3      [Luminiferous_aether, Special_relativity, Time...
# 4            [Corn_oil, Maize, Southern_Africa, Mayotte]
# ...                                                  ...
# 21641  [Fusarium, Cornea, Human, United_Nations, Unit...
# 21642  [Scheme_programming_language, Functional_progr...
# 21643  [Horatio_Nelson,_1st_Viscount_Nelson, England,...
# 21644  [Scheme_programming_language, Functional_progr...
# 21645  [Jehovah, Switzerland, Energy, Photosynthesis,...
#
# [21646 rows x 1 columns]

# %%
# 2. a function that iterates over the simplified paths and extracts the corresponding vector embeddings from the articles_df

def get_embeddings(simplified_path, articles_df):
    embeddings = articles_df[articles_df['article'].isin(simplified_path)]['embeddings'].tolist()
    
    # Only return embeddings if the number of embeddings matches the length of the simplified_path
    if len(embeddings) == len(simplified_path):
        return embeddings
    else:
        return None  # If the lengths don't match, return None (indicating invalid row)

# Apply the function to the DataFrame
df['embeddings'] = df['simplified_path'].apply(lambda x: get_embeddings(x, articles_df))

# Drop rows where embeddings are None (invalid rows)
df = df.dropna(subset=['embeddings'])

# Reset index after dropping rows (optional, depending on your preference)
df.reset_index(drop=True, inplace=True)
# Out:
# /var/folders/sj/219f9qbn3y15yynshcyrrp3c0000gn/T/ipykernel_4824/1976197712.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['embeddings'] = df['simplified_path'].apply(lambda x: get_embeddings(x, articles_df))

# %%
df.shape
# Out:
# (21535, 2)

# %%
l_paths_df.shape
# Out:
# (21646, 15)

# %%
# the target article is the last element in the simplified path
df = df.copy()
# Extract the target article and target embeddings
df['target_article'] = df['simplified_path'].apply(lambda x: x[-1])
df['target_embedding'] = df['embeddings'].apply(lambda x: x[-1])

# Remove the last element from simplified_path and embeddings
df['simplified_path'] = df['simplified_path'].apply(lambda x: x[1:-1])
df['embeddings'] = df['embeddings'].apply(lambda x: x[1:-1])

# %%
# get the shape of the first element of the embeddings column

df.head(5)
# Out:
#                                      simplified_path  \
# 0  [India, Bay_of_Bengal, Indian_Ocean, Africa, G...
# 1       [Computer_science, Internet, World_Wide_Web]
# 2   [United_States, Judaism, Olive_oil, Tree, Apple]
# 3                         [Special_relativity, Time]
# 4                           [Maize, Southern_Africa]
#
#                                           embeddings target_article  \
# 0  [[-0.0125789958983659, 0.0561332367360591, -0....          Zebra
# 1  [[-0.0637916252017021, -0.0175681598484516, -0...      Telephone
# 2  [[-0.0554433651268482, 0.0141023732721805, -0....          Cider
# 3  [[-0.0204615797847509, -0.0378306880593299, 0....          Clock
# 4  [[-0.0457388870418071, 0.0483880490064621, -0....        Mayotte
#
#                                     target_embedding
# 0  [-0.1285928189754486, 0.0847383961081504, -0.0...
# 1  [-0.0529951564967632, -0.06702421605587, -0.01...
# 2  [0.0643062964081764, -0.0023302482441067, 0.00...
# 3  [-0.074506863951683, 0.054837942123413, -0.021...
# 4  [-0.0358180664479732, 0.0611802525818347, -0.0...

# %%
df[~df.apply(lambda row: len(row['embeddings']) == len(row['simplified_path']), axis=1)]
# Out:
# Empty DataFrame
# Columns: [simplified_path, embeddings, target_article, target_embedding]
# Index: []

# %%
# 3. compute the cosine similarty between all the articles and the target article (add a new column to the df (list of cosine similarities))

from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

df2 = df.copy()

def get_cosine_similarities(target_embedding, embeddings):
    cos_dist_list = []
    for embedding in embeddings:
        cos_dist_list.append(cosine_similarity(np.array(target_embedding).reshape(1, -1), np.array(embedding).reshape(1, -1)))
    return cos_dist_list

df2['cosine_similarities'] = df2.apply(lambda x: get_cosine_similarities(x['target_embedding'], x['embeddings']), axis=1)

# %%
# 5. then iterate over the df to average the cosine similarities for each article
def calculate_avg_cosine_dist(df, count_cutoff=30, scaling=None):

    # Initialize an empty DataFrame to store results
    avg_cosine_dist_df = pd.DataFrame(columns=['article', 'n_appearances', 'avg_cosine_dist'])
    avg_cosine_dist_df.set_index('article', inplace=True)

    # Iterate through each row to calculate weights
    for _, row in df.iterrows():
        cosine_similarities = row['cosine_similarities']
        simplified_path = row['simplified_path']

        for idx, article in enumerate(simplified_path):
            if article not in avg_cosine_dist_df.index:
                avg_cosine_dist_df.loc[article] = [0, 0.0]

            # Update counts and weighted sums
            avg_cosine_dist_df.at[article, 'n_appearances'] += 1
            avg_cosine_dist_df.at[article, 'avg_cosine_dist'] += cosine_similarities[idx]

    # Calculate the weighted average by dividing weighted sum by counts
    avg_cosine_dist_df['avg_cosine_dist'] = avg_cosine_dist_df['avg_cosine_dist'] / avg_cosine_dist_df['n_appearances']

    # Filter out articles that appear less than the cutoff
    avg_cosine_dist_df = avg_cosine_dist_df[avg_cosine_dist_df['n_appearances'] >= count_cutoff]

    print(f"Number of unique articles after weighting: {avg_cosine_dist_df.shape[0]}")

    return avg_cosine_dist_df#.reset_index()

avg_cosine_dist_df = calculate_avg_cosine_dist(df2, count_cutoff=30)
# Out:
# Number of unique articles after weighting: 496

# %%
avg_cosine_dist_df.sort_values('avg_cosine_dist', ascending=False)
# Out:
#                                   n_appearances  avg_cosine_dist
# article
# Whale_shark                                78.0         0.561491
# Shark                                      94.0         0.523529
# Whale                                      66.0         0.462966
# Western_Roman_Empire                       30.0         0.459886
# Sputnik_1                                  42.0         0.452991
# ...                                         ...              ...
# Space_Shuttle_Columbia                     41.0         0.214021
# Calcium                                    41.0         0.212621
# 17th_century                               52.0         0.211912
# Yellowstone_National_Park                  33.0         0.210304
# Star_Wars_Episode_IV__A_New_Hope           35.0         0.210135
#
# [496 rows x 2 columns]

# %%
# suposedly faster alternative

def calculate_avg_cosine_dist(df, count_cutoff=30, scaling=None):
    from collections import defaultdict

    # Use dictionaries to aggregate counts and cosine sums
    article_counts = defaultdict(int)
    article_cosine_sums = defaultdict(float)

    # Iterate through each row to calculate weights
    for _, row in df.iterrows():
        cosine_similarities = row['cosine_similarities']
        simplified_path = row['simplified_path']

        for idx, article in enumerate(simplified_path):
            article_counts[article] += 1
            article_cosine_sums[article] += cosine_similarities[idx]

    # Create a DataFrame from the aggregated data
    avg_cosine_dist_df = pd.DataFrame({
        'article': list(article_counts.keys()),
        'n_appearances': list(article_counts.values()),
        'avg_cosine_dist': [article_cosine_sums[article] / article_counts[article] 
                            for article in article_counts.keys()]
    })

    # Filter out articles that appear less than the cutoff
    avg_cosine_dist_df = avg_cosine_dist_df[avg_cosine_dist_df['n_appearances'] >= count_cutoff]

    print(f"Number of unique articles after weighting: {avg_cosine_dist_df.shape[0]}")

    return avg_cosine_dist_df.reset_index(drop=True)

# %%
# a function that from an article name iterates over the paths_df and return all rows with the article name in the simplified path
def get_article_paths(article_name, paths_df):
    return paths_df[paths_df['simplified_path'].apply(lambda x: article_name in x)]

# %%
get_article_paths('Whale_shark', paths_df=l_paths_df).head(50)
# Out:
#         hashedIpAddress   timestamp  durationInSec  \
# 18     098c807976ebd156  1306774721             41
# 95     0c013a70550e6011  1257357145            199
# 104    5f85cf827a29ac5a  1352760115            161
# 235    3c4bf61c4a447176  1345664543             10
# 254    25ad32b66245e04b  1388605778             46
# 683    567951c61a5d5c91  1254226509            148
# 721    5164c8e415d73ec0  1349900154             72
# 854    49ff80356d88b407  1351112498            109
# 1168   398239e42f686267  1248803537             88
# 1186   4e5bc9b510f05358  1249094043             95
# 1600   33c43d4567a0d5be  1259136755             56
# 1677   0dba31954dec0adc  1248812013             61
# 2192   1063f6f13b08da3f  1259369838             99
# 2296   26743a541079392c  1375242938             24
# 2569   56b3ceeb5a14c5d3  1248691286             81
# 2631   3a11233c52f824f8  1330337794            143
# 2902   0a79cbca7c0055d2  1254515683            167
# 3003   69dc74ee2b9a4a8e  1249709992            204
# 3244   5e8491514647a082  1366787765             71
# 3379   51ba6aab3e965015  1307491714             78
# 3618   3c9baa705f730ade  1344828476             85
# 3817   1bcd2eea720e47dd  1251176915             99
# 4024   64703dab79249086  1378099254            153
# 4036   0a66aeb87f2f7d88  1238792120            148
# 4348   79a07830536ad2f2  1249069390             99
# 6441   6c630073263514fb  1249786901            194
# 6564   1fe7b96176c3ee70  1248682812            199
# 7587   2b79b5885015be84  1263231624            135
# 7633   50c6d5de10d918b2  1248891695            143
# 7682   7fc49043433c131d  1250017477             25
# 8098   66a39a020d906104  1251096905            772
# 8397   0299542414c3f20a  1259776669             77
# 9274   6b039e9953cf075e  1239882117            139
# 9730   669942064c6539b5  1325010806            141
# 10194  25b1c22e19335a03  1389122092             80
# 10224  340b53d4151cd0a9  1251083309             40
# 11731  1149572764825159  1272994223            171
# 11931  24e9fc2e2d40b81a  1275164962             59
# 12582  101779c07d4d00f0  1265211979            255
# 12884  4cf9ec5922648fc9  1304369683             43
# 16883  301eee446776d2ed  1366205519             55
# 17417  75bd20c663d02c8f  1365713537             29
# 17985  636b9ddc1691d16b  1239083914            109
# 18007  577e021f25d1b1e9  1260232828            715
# 18031  50e2af540afe5b4e  1249101267             85
# 18123  0d57c8c57d75e2f5  1284046519            150
# 18156  4881bb716fd84b17  1249769147            182
# 18188  5bb962812f33398d  1248917937            197
# 18203  28b4449477d951a8  1238178044            254
# 18303  410d794a2e0e3b9e  1350882127             81
#
#                                                     path  rating  finished  \
# 18     Blacktip_reef_shark;Shark;Whale_shark;Mexico;I...     NaN      True
# 95     Computer;Great_Britain;Ice_age;Greenland;Arcti...     3.0      True
# 104    Great_Salt_Lake;Fish;Whale_shark;Shark;Blue_shark     NaN      True
# 235    Bird;Fish;Whale_shark;Basking_shark;Great_whit...     NaN      True
# 254    Flood;Sea;Ocean;Krill;Whale_shark;Shark;Jaws_(...     NaN      True
# 683    Pope_Pius_XII;Europe;Asia;Japan;Pacific_Ocean;...     NaN      True
# 721    Bird;Vertebrate;Whale;Dolphin;Fish;Whale_shark...     NaN      True
# 854        Bird;Fish;Whale_shark;Shark;Great_white_shark     2.0      True
# 1168   Lake_Victoria;River;Ocean;Fish;Whale_shark;Sha...     1.0      True
# 1186   Styracosaurus;Fossil;Vertebrate;Fish;Whale_sha...     2.0      True
# 1600   Pupil;Fish;Whale_shark;Japan;Attack_on_Pearl_H...     2.0      True
# 1677              Miocene;Fish;Whale_shark;Basking_shark     1.0      True
# 2192   Styracosaurus;Chordate;Vertebrate;Fish;Whale_s...     NaN      True
# 2296                        Pupil;Fish;Whale_shark;Shark     1.0      True
# 2569   Styracosaurus;Dinosaur;Turtle;Seychelles;Tuna;...     4.0      True
# 2631   Atlanta,_Georgia;United_States;Pacific_Ocean;A...     NaN      True
# 2902         Glass;Biology;Animal;Fish;Whale_shark;Shark     3.0      True
# 3003   Copper;Barnacle;Animal;Fish;Whale_shark;Shark;...     2.0      True
# 3244                    Whale_shark;Tanzania;Rwanda;Hutu     NaN      True
# 3379       Rama;Asia;Earth;Animal;Fish;Whale_shark;Shark     NaN      True
# 3618   Serbia;North_Sea;Atlantic_Ocean;Ocean;Fish;Wha...     NaN      True
# 3817   Bandicoot;Animal;Fish;Whale_shark;<;Whale_shar...     NaN      True
# 4024   Tehran;Persian_Gulf;Red_Sea;Invertebrate;Mamma...     NaN      True
# 4036   Alcohol;Ethanol;Beer;Fish;Whale_shark;Krill;An...     3.0      True
# 4348   Oxford;River_Thames;North_Sea;English_Channel;...     3.0      True
# 6441   The_Shawshank_Redemption;DVD;<;Film;<;Spring_(...     NaN      True
# 6564   The_Shawshank_Redemption;Film;United_States;Pa...     2.0      True
# 7587   Mormon;Christianity;Oceania;Australia;Pacific_...     NaN      True
# 7633   Whale_shark;Mexico;Salsa_music;Hip_hop_music;I...     NaN      True
# 7682             Bandicoot;Animal;Fish;Whale_shark;Shark     NaN      True
# 8098   Whale_shark;Scientific_classification;Aristotl...     3.0      True
# 8397   Siege;Vietnam;South_China_Sea;Ocean;Fish;Whale...     4.0      True
# 9274   Kofi_Annan;Economics;Ancient_Greece;Black_Sea;...     3.0      True
# 9730   Atlanta,_Georgia;United_States;Pacific_Ocean;C...     3.0      True
# 10194  CS_gas;England;Atlantic_Ocean;Ocean;Animal;Fis...     1.0      True
# 10224        Whale_shark;South_Africa;Zimbabwe;Sculpture     2.0      True
# 11731  Timbuktu;Sahara;Crocodile;Vertebrate;Fish;Whal...     3.0      True
# 11931  Styracosaurus;Animal;<;Chordate;Vertebrate;Fis...     NaN      True
# 12582  Whale_shark;Thailand;<;Thailand;Malaysia;Chris...     2.0      True
# 12884             Whale_shark;Family;Sociology;Education     1.0      True
# 16883  Whale_shark;South_Africa;Portugal;Spain;Mexico...     NaN      True
# 17417       Whale_shark;Shark;Fossil_record;Paleontology     NaN      True
# 17985  Giraffe;Kenya;<;Animal;Reptile;<;Fish;Whale_sh...     NaN      True
# 18007  Magma;Earth;Pacific_Ocean;Australia;Great_Barr...     NaN      True
# 18031  Cattle;Animal;Fish;Whale_shark;Shark;Great_whi...     2.0      True
# 18123  Last_Supper;God;Nature;Animal;Fish;Whale_shark...     NaN      True
# 18156  Number;Group_(mathematics);Set;19th_century;Fi...     4.0      True
# 18188  George_Washington;Hippopotamus;Chordate;Verteb...     NaN      True
# 18203  Big_Bang;Science;Nature;Mammal;Animal;<;Whale;...     3.0      True
# 18303  Effects_of_nuclear_explosions;Eye;Fish;Whale_s...     2.0      True
#
#       failure_reason                  start_article          target_article  \
# 18              None            Blacktip_reef_shark               Economics
# 95              None                       Computer                   Whale
# 104             None                Great_Salt_Lake              Blue_shark
# 235             None                           Bird       Great_white_shark
# 254             None                          Flood             Jaws_(film)
# 683             None                  Pope_Pius_XII                   Whale
# 721             None                           Bird       Great_white_shark
# 854             None                           Bird       Great_white_shark
# 1168            None                  Lake_Victoria           Basking_shark
# 1186            None                  Styracosaurus      Cookiecutter_shark
# 1600            None                          Pupil  Attack_on_Pearl_Harbor
# 1677            None                        Miocene           Basking_shark
# 2192            None                  Styracosaurus      Cookiecutter_shark
# 2296            None                          Pupil                   Shark
# 2569            None                  Styracosaurus      Cookiecutter_shark
# 2631            None               Atlanta,_Georgia             Whale_shark
# 2902            None                          Glass                   Shark
# 3003            None                         Copper              Bull_shark
# 3244            None                    Whale_shark                    Hutu
# 3379            None                           Rama                   Shark
# 3618            None                         Serbia             Tiger_shark
# 3817            None                      Bandicoot                   Shark
# 4024            None                         Tehran             Whale_shark
# 4036            None                        Alcohol         Antarctic_krill
# 4348            None                         Oxford             Whale_shark
# 6441            None       The_Shawshank_Redemption             Tiger_shark
# 6564            None       The_Shawshank_Redemption             Tiger_shark
# 7587            None                         Mormon                   Shark
# 7633            None                    Whale_shark               Sculpture
# 7682            None                      Bandicoot                   Shark
# 8098            None                    Whale_shark                  Apollo
# 8397            None                          Siege             Whale_shark
# 9274            None                     Kofi_Annan             Whale_shark
# 9730            None               Atlanta,_Georgia             Whale_shark
# 10194           None                         CS_gas             Zebra_shark
# 10224           None                    Whale_shark               Sculpture
# 11731           None                       Timbuktu           Basking_shark
# 11931           None                  Styracosaurus      Cookiecutter_shark
# 12582           None                    Whale_shark                  Banana
# 12884           None                    Whale_shark               Education
# 16883           None                    Whale_shark           Hernán_Cortés
# 17417           None                    Whale_shark            Paleontology
# 17985           None                        Giraffe             Zebra_shark
# 18007           None                          Magma             Tiger_shark
# 18031           None                         Cattle       Great_white_shark
# 18123           None                    Last_Supper              Bull_shark
# 18156           None                         Number              Blue_Whale
# 18188           None              George_Washington           Basking_shark
# 18203           None                       Big_Bang       Great_white_shark
# 18303           None  Effects_of_nuclear_explosions     Blacktip_reef_shark
#
#        identifier                                          full_path  \
# 18           5887  [Blacktip_reef_shark, Shark, Whale_shark, Mexi...
# 95           9798  [Computer, Great_Britain, Ice_age, Greenland, ...
# 104         16899  [Great_Salt_Lake, Fish, Whale_shark, Shark, Bl...
# 235          5634  [Bird, Fish, Whale_shark, Basking_shark, Great...
# 254         14534  [Flood, Sea, Ocean, Krill, Whale_shark, Shark,...
# 683         30739  [Pope_Pius_XII, Europe, Asia, Japan, Pacific_O...
# 721          5634  [Bird, Vertebrate, Whale, Dolphin, Fish, Whale...
# 854          5634  [Bird, Fish, Whale_shark, Shark, Great_white_s...
# 1168        22249  [Lake_Victoria, River, Ocean, Fish, Whale_shar...
# 1186        36260  [Styracosaurus, Fossil, Vertebrate, Fish, Whal...
# 1600        31363  [Pupil, Fish, Whale_shark, Japan, Attack_on_Pe...
# 1677        25716        [Miocene, Fish, Whale_shark, Basking_shark]
# 2192        36260  [Styracosaurus, Chordate, Vertebrate, Fish, Wh...
# 2296        31372                  [Pupil, Fish, Whale_shark, Shark]
# 2569        36260  [Styracosaurus, Dinosaur, Turtle, Seychelles, ...
# 2631         3538  [Atlanta,_Georgia, United_States, Pacific_Ocea...
# 2902        16178  [Glass, Biology, Animal, Fish, Whale_shark, Sh...
# 3003        10079  [Copper, Barnacle, Animal, Fish, Whale_shark, ...
# 3244        41447              [Whale_shark, Tanzania, Rwanda, Hutu]
# 3379        31895  [Rama, Asia, Earth, Animal, Fish, Whale_shark,...
# 3618        34132  [Serbia, North_Sea, Atlantic_Ocean, Ocean, Fis...
# 3817         4285  [Bandicoot, Animal, Fish, Whale_shark, Whale_s...
# 4024        37179  [Tehran, Persian_Gulf, Red_Sea, Invertebrate, ...
# 4036         1588  [Alcohol, Ethanol, Beer, Fish, Whale_shark, Kr...
# 4348        28830  [Oxford, River_Thames, North_Sea, English_Chan...
# 6441        37953  [The_Shawshank_Redemption, DVD, Film, Spring_(...
# 6564        37953  [The_Shawshank_Redemption, Film, United_States...
# 7587        26133  [Mormon, Christianity, Oceania, Australia, Pac...
# 7633        41449  [Whale_shark, Mexico, Salsa_music, Hip_hop_mus...
# 7682         4285      [Bandicoot, Animal, Fish, Whale_shark, Shark]
# 8098        41442  [Whale_shark, Scientific_classification, Arist...
# 8397        34452  [Siege, Vietnam, South_China_Sea, Ocean, Fish,...
# 9274        21809  [Kofi_Annan, Economics, Ancient_Greece, Black_...
# 9730         3538  [Atlanta,_Georgia, United_States, Pacific_Ocea...
# 10194        7093  [CS_gas, England, Atlantic_Ocean, Ocean, Anima...
# 10224       41449   [Whale_shark, South_Africa, Zimbabwe, Sculpture]
# 11731       38459  [Timbuktu, Sahara, Crocodile, Vertebrate, Fish...
# 11931       36260  [Styracosaurus, Animal, Chordate, Vertebrate, ...
# 12582       41443  [Whale_shark, Thailand, Thailand, Malaysia, Ch...
# 12884       41445        [Whale_shark, Family, Sociology, Education]
# 16883       41446  [Whale_shark, South_Africa, Portugal, Spain, M...
# 17417       41448  [Whale_shark, Shark, Fossil_record, Paleontology]
# 17985       16093  [Giraffe, Kenya, Animal, Reptile, Fish, Whale_...
# 18007       23913  [Magma, Earth, Pacific_Ocean, Australia, Great...
# 18031        7986  [Cattle, Animal, Fish, Whale_shark, Shark, Gre...
# 18123       22370  [Last_Supper, God, Nature, Animal, Fish, Whale...
# 18156       28006  [Number, Group_(mathematics), Set, 19th_centur...
# 18188       15874  [George_Washington, Hippopotamus, Chordate, Ve...
# 18203        5467  [Big_Bang, Science, Nature, Mammal, Animal, Wh...
# 18303       12604  [Effects_of_nuclear_explosions, Eye, Fish, Wha...
#
#                                          simplified_path  distance  \
# 18     [Blacktip_reef_shark, Shark, Whale_shark, Mexi...       3.0
# 95     [Computer, Great_Britain, Ice_age, Greenland, ...       3.0
# 104    [Great_Salt_Lake, Fish, Whale_shark, Shark, Bl...       3.0
# 235    [Bird, Fish, Whale_shark, Basking_shark, Great...       3.0
# 254    [Flood, Sea, Ocean, Krill, Whale_shark, Shark,...       3.0
# 683    [Pope_Pius_XII, Europe, Asia, Japan, Fishing, ...       3.0
# 721    [Bird, Vertebrate, Whale, Dolphin, Fish, Whale...       3.0
# 854    [Bird, Fish, Whale_shark, Shark, Great_white_s...       3.0
# 1168   [Lake_Victoria, River, Ocean, Fish, Whale_shar...       3.0
# 1186   [Styracosaurus, Fossil, Vertebrate, Fish, Whal...       3.0
# 1600   [Pupil, Fish, Whale_shark, Japan, Attack_on_Pe...       3.0
# 1677         [Miocene, Fish, Whale_shark, Basking_shark]       3.0
# 2192   [Styracosaurus, Chordate, Vertebrate, Fish, Wh...       3.0
# 2296                   [Pupil, Fish, Whale_shark, Shark]       3.0
# 2569   [Styracosaurus, Dinosaur, Turtle, Seychelles, ...       3.0
# 2631   [Atlanta,_Georgia, United_States, Pacific_Ocea...       3.0
# 2902   [Glass, Biology, Animal, Fish, Whale_shark, Sh...       3.0
# 3003   [Copper, Barnacle, Animal, Fish, Whale_shark, ...       3.0
# 3244               [Whale_shark, Tanzania, Rwanda, Hutu]       3.0
# 3379   [Rama, Asia, Earth, Animal, Fish, Whale_shark,...       3.0
# 3618   [Serbia, North_Sea, Atlantic_Ocean, Ocean, Fis...       3.0
# 3817       [Bandicoot, Animal, Fish, Whale_shark, Shark]       3.0
# 4024   [Tehran, Persian_Gulf, Red_Sea, Invertebrate, ...       3.0
# 4036   [Alcohol, Ethanol, Beer, Fish, Whale_shark, Kr...       3.0
# 4348   [Oxford, River_Thames, North_Sea, English_Chan...       3.0
# 6441   [The_Shawshank_Redemption, Spring_(season), At...       3.0
# 6564   [The_Shawshank_Redemption, Film, United_States...       3.0
# 7587   [Mormon, Christianity, Oceania, Australia, Pac...       3.0
# 7633   [Whale_shark, Mexico, Salsa_music, Hip_hop_mus...       3.0
# 7682       [Bandicoot, Animal, Fish, Whale_shark, Shark]       3.0
# 8098   [Whale_shark, Scientific_classification, Arist...       3.0
# 8397   [Siege, Vietnam, South_China_Sea, Ocean, Fish,...       3.0
# 9274   [Kofi_Annan, Economics, Ancient_Greece, Black_...       3.0
# 9730   [Atlanta,_Georgia, United_States, Pacific_Ocea...       3.0
# 10194  [CS_gas, England, Atlantic_Ocean, Ocean, Anima...       3.0
# 10224   [Whale_shark, South_Africa, Zimbabwe, Sculpture]       3.0
# 11731  [Timbuktu, Sahara, Crocodile, Vertebrate, Fish...       3.0
# 11931  [Styracosaurus, Chordate, Vertebrate, Fish, Wh...       3.0
# 12582                      [Whale_shark, Belize, Banana]       2.0
# 12884        [Whale_shark, Family, Sociology, Education]       2.0
# 16883  [Whale_shark, South_Africa, Portugal, Spain, M...       2.0
# 17417  [Whale_shark, Shark, Fossil_record, Paleontology]       2.0
# 17985  [Giraffe, Animal, Fish, Whale_shark, Shark, Ze...       4.0
# 18007  [Magma, Earth, Pacific_Ocean, Australia, Great...       4.0
# 18031  [Cattle, Animal, Fish, Whale_shark, Shark, Gre...       4.0
# 18123  [Last_Supper, God, Nature, Animal, Fish, Whale...       4.0
# 18156  [Number, Group_(mathematics), Set, 19th_centur...       4.0
# 18188  [George_Washington, Hippopotamus, Chordate, Ve...       4.0
# 18203  [Big_Bang, Science, Nature, Mammal, Whale, Fis...       4.0
# 18303  [Effects_of_nuclear_explosions, Eye, Fish, Wha...       4.0
#
#        full_path_length  simplified_path_length
# 18                    5                       5
# 95                    9                       9
# 104                   4                       4
# 235                   4                       4
# 254                   6                       6
# 683                   8                       7
# 721                   7                       7
# 854                   4                       4
# 1168                  6                       6
# 1186                  6                       6
# 1600                  4                       4
# 1677                  3                       3
# 2192                  6                       6
# 2296                  3                       3
# 2569                  8                       8
# 2631                  7                       7
# 2902                  5                       5
# 3003                  6                       6
# 3244                  3                       3
# 3379                  6                       6
# 3618                  7                       7
# 3817                  5                       4
# 4024                  8                       8
# 4036                  6                       6
# 4348                  8                       8
# 6441                  9                       7
# 6564                  9                       9
# 7587                  8                       8
# 7633                  7                       7
# 7682                  4                       4
# 8098                  8                       8
# 8397                  5                       5
# 9274                  8                       8
# 9730                  6                       6
# 10194                 8                       8
# 10224                 3                       3
# 11731                 6                       6
# 11931                 7                       6
# 12582                 9                       2
# 12884                 3                       3
# 16883                 5                       5
# 17417                 3                       3
# 17985                 7                       5
# 18007                10                      10
# 18031                 5                       5
# 18123                 7                       7
# 18156                11                      11
# 18188                 8                       7
# 18203                 9                       8
# 18303                 5                       5
